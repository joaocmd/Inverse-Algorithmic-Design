# %%
from recognition import *

import matplotlib.pyplot as plt

# %%
x = [10, 20]
y = [0] * len(x)

fig = plt.figure(figsize=(5, 0.5))
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

ax.set_yticks([])
ax.set_xticks([10, 15, 20, 21])
plt.scatter(x, y)
plt.scatter([21], [0])

plt.savefig('cluster-bad.png', bbox_inches="tight")

# %%
x = [10]
y = [0] * len(x)

fig = plt.figure(figsize=(5, 0.5))
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

ax.set_yticks([])
ax.set_xticks([10, 15, 20, 21])
plt.scatter(x, y)
plt.scatter([20, 21], [0, 0])

plt.savefig('cluster-good.png', bbox_inches="tight")

# %%
original = cv2.imread('original.png')
plt.imshow(original)
plt.show()

walls_closed = cv2.imread('walls.png', cv2.IMREAD_GRAYSCALE)
walls_closed = cv2.threshold(walls_closed, 0, 255, cv2.THRESH_OTSU)[1]
plt.imshow(walls_closed, cmap='gray')
plt.show()

doors_pixels = cv2.imread('doors.png', cv2.IMREAD_GRAYSCALE)
doors_pixels = cv2.threshold(doors_pixels, 0, 255, cv2.THRESH_OTSU)[1]
plt.imshow(doors_pixels, cmap='gray')
plt.show()

windows_pixels = cv2.imread('windows.png', cv2.IMREAD_GRAYSCALE)
windows_pixels = cv2.threshold(windows_pixels, 0, 255, cv2.THRESH_OTSU)[1]
plt.imshow(windows_pixels, cmap='gray')
plt.show()
##

# %%
## Vectorization and adding semantics
room_cnts = get_room_contours_from_wall(walls_closed)
room_cnts = simplify_contours(room_cnts)

# %%
walls = contours_to_walls(room_cnts,)
walls = tuple({'points': w} for w in tqdm(walls))
# walls = tuple({'points': w, 'width': calculate_width(w, walls_closed)} for w in tqdm(walls, disable=not verbose))
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 219214.49it/s]

# %%
def show_img(im, walls=None, elements=None):
    im = np.expand_dims(im, axis=2).repeat(3, axis=2) 

    if walls:
        for w in walls:
            s, e = w['points'][0], w['points'][1]
            im = cv2.line(im, np.intp(s), np.intp(e), color=(200, 130, 0), thickness=2)
            im = cv2.circle(im, np.intp(s), color=(255, 0, 0), radius=5, thickness=2)
            im = cv2.circle(im, np.intp(e), color=(255, 0, 0), radius=5, thickness=2)

    if elements:
        for el in elements:
            s, e = el['points'][0], el['points'][1]
            ps, pe = el['perp'][0], el['perp'][1]

            color = (0, 255, 0) if el['type'] == 'window' else (0, 0, 255)
            pcolor = (50, 50, 210) if el['type'] == 'window' else (50, 210, 50) 
            im = cv2.line(im, np.intp(s), np.intp(e), color=color, thickness=2)
            im = cv2.line(im, np.intp(ps), np.intp(pe), color=pcolor, thickness=2)

    plt.figure(figsize=(10,10))
    plt.imshow(im)

show_img(walls_closed, walls)

# %%
doors = get_opening_lines(doors_pixels)
doors = tuple({'points': d, 'type': 'door'} for d in doors)
# FIXME: classify door as to be run after attaching to walls

windows = get_opening_lines(windows_pixels)
windows = tuple({'points': w, 'type': 'window'} for w in windows)

# %%
elements = tuple(el for el in doors + windows if np.linalg.norm(vector(el['points'])) > 10) 
print(len(elements))
# Out:
# 35

# %%
element_lines =  tuple({**e, 'perp': element_segment(e['points'])} for e in elements)
# element_lines =  tuple({**e, 'perp': e['points']} for e in doors + windows)
print(element_lines[0])
show_img(walls_closed, walls, element_lines)
# Out:
# {'points': array([[181. , 434.5],
#        [226. , 434.5]], dtype=float32), 'type': 'door', 'perp': array([[203.5, 429.5],
#        [203.5, 439.5]], dtype=float32)}

# %%
walls = attach_openings(walls, elements, True)
walls
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 618.38it/s]
# ({'points': array([[170. , 368.5],
#          [260. , 369. ]], dtype=float32),
#   'elements': [{'points': array([[197., 368.],
#            [224., 368.]], dtype=float32),
#     'type': 'door'}]},
#  {'points': array([[170. , 368.5],
#          [171.5, 433.5]], dtype=float32)},
#  {'points': array([[170. , 368.5],
#          [169. , 324. ]], dtype=float32),
#   'elements': [{'points': array([[170., 358.],
#            [170., 334.]], dtype=float32),
#     'type': 'door'}]},
#  {'points': array([[260. , 369. ],
#          [258.5, 434. ]], dtype=float32)},
#  {'points': array([[258.5, 434. ],
#          [171.5, 433.5]], dtype=float32),
#   'elements': [{'points': array([[181. , 434.5],
#            [226. , 434.5]], dtype=float32),
#     'type': 'door'}]},
#  {'points': array([[258.5, 434. ],
#          [249. , 508. ]], dtype=float32),
#   'elements': [{'points': array([[258.5, 483. ],
#            [258.5, 454. ]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[258.5, 434. ],
#          [260. , 503. ]], dtype=float32)},
#  {'points': array([[171.5, 433.5],
#          [ 47.5, 432.5]], dtype=float32),
#   'elements': [{'points': array([[ 57. , 434.5],
#            [102. , 434.5]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[ 48.5, 325.5],
#          [169. , 324. ]], dtype=float32)},
#  {'points': array([[ 48.5, 325.5],
#          [ 47.5, 432.5]], dtype=float32),
#   'elements': [{'points': array([[ 47., 426.],
#            [ 47., 409.]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[ 48.5, 325.5],
#          [ 47.5, 255. ]], dtype=float32),
#   'elements': [{'points': array([[ 47.5, 310. ],
#            [ 47.5, 290. ]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[169., 324.],
#          [168., 255.]], dtype=float32),
#   'elements': [{'points': array([[169.89601, 281.0043 ],
#            [170.9792 , 307.00082]], dtype=float32),
#     'type': 'door'}]},
#  {'points': array([[ 47.5, 255. ],
#          [168. , 255. ]], dtype=float32)},
#  {'points': array([[ 47.5, 255. ],
#          [ 49.5,  98.5]], dtype=float32),
#   'elements': [{'points': array([[ 48., 226.],
#            [ 48., 207.]], dtype=float32),
#     'type': 'window'},
#    {'points': array([[ 48., 122.],
#            [ 48., 105.]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[168. , 255. ],
#          [172. , 212.5]], dtype=float32),
#   'elements': [{'points': array([[171., 246.],
#            [171., 221.]], dtype=float32),
#     'type': 'door'}]},
#  {'points': array([[642. , 242.5],
#          [724.5, 242. ]], dtype=float32)},
#  {'points': array([[642. , 242.5],
#          [631.5, 300. ]], dtype=float32)},
#  {'points': array([[642. , 242.5],
#          [639.5, 220. ]], dtype=float32)},
#  {'points': array([[724.5, 242. ],
#          [726. , 322. ]], dtype=float32),
#   'elements': [{'points': array([[726., 309.],
#            [726., 293.]], dtype=float32),
#     'type': 'door'}]},
#  {'points': array([[724.5, 242. ],
#          [728. , 219. ]], dtype=float32)},
#  {'points': array([[726. , 322. ],
#          [791. , 323.5]], dtype=float32),
#   'elements': [{'points': array([[740., 324.],
#            [754., 324.]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[726., 322.],
#          [687., 325.]], dtype=float32),
#   'elements': [{'points': array([[701. , 323.5],
#            [719. , 323.5]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[645. , 320. ],
#          [631.5, 300. ]], dtype=float32)},
#  {'points': array([[645., 320.],
#          [687., 325.]], dtype=float32)},
#  {'points': array([[631.5, 300. ],
#          [614. , 292. ]], dtype=float32)},
#  {'points': array([[728. , 219. ],
#          [791.5, 219.5]], dtype=float32),
#   'elements': [{'points': array([[733., 219.],
#            [758., 219.]], dtype=float32),
#     'type': 'door'}]},
#  {'points': array([[791.5, 219.5],
#          [791. , 323.5]], dtype=float32)},
#  {'points': array([[791.5, 219.5],
#          [792. , 139. ]], dtype=float32),
#   'elements': [{'points': array([[793.5, 202. ],
#            [793.5, 173. ]], dtype=float32),
#     'type': 'door'}]},
#  {'points': array([[595. , 218.5],
#          [639.5, 220. ]], dtype=float32),
#   'elements': [{'points': array([[612. , 219.5],
#            [633. , 219.5]], dtype=float32),
#     'type': 'door'}]},
#  {'points': array([[595. , 218.5],
#          [594. , 289. ]], dtype=float32)},
#  {'points': array([[595. , 218.5],
#          [595. , 138.5]], dtype=float32),
#   'elements': [{'points': array([[594., 199.],
#            [594., 174.]], dtype=float32),
#     'type': 'door'}]},
#  {'points': array([[594., 289.],
#          [574., 293.]], dtype=float32)},
#  {'points': array([[594., 289.],
#          [614., 292.]], dtype=float32)},
#  {'points': array([[262. , 212. ],
#          [335.5, 212.5]], dtype=float32)},
#  {'points': array([[262., 212.],
#          [262., 289.]], dtype=float32)},
#  {'points': array([[262. , 212. ],
#          [172. , 212.5]], dtype=float32),
#   'elements': [{'points': array([[201. , 212.5],
#            [226. , 212.5]], dtype=float32),
#     'type': 'door'}]},
#  {'points': array([[335.5, 212.5],
#          [335.5, 289.5]], dtype=float32),
#   'elements': [{'points': array([[336.5, 260. ],
#            [336.5, 241. ]], dtype=float32),
#     'type': 'door'}]},
#  {'points': array([[335.5, 212.5],
#          [337. ,  98. ]], dtype=float32)},
#  {'points': array([[335.5, 289.5],
#          [262. , 289. ]], dtype=float32)},
#  {'points': array([[335.5, 289.5],
#          [448.5, 290. ]], dtype=float32),
#   'elements': [{'points': array([[344., 290.],
#            [367., 290.]], dtype=float32),
#     'type': 'door'}]},
#  {'points': array([[792. , 139. ],
#          [595. , 138.5]], dtype=float32),
#   'elements': [{'points': array([[674., 138.],
#            [714., 138.]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[792., 139.],
#          [805., 134.]], dtype=float32)},
#  {'points': array([[595. , 138.5],
#          [453.5, 139.5]], dtype=float32),
#   'elements': [{'points': array([[558., 138.],
#            [586., 138.]], dtype=float32),
#     'type': 'door'},
#    {'points': array([[472. , 138.5],
#            [510. , 138.5]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[172. , 212.5],
#          [171. ,  99. ]], dtype=float32)},
#  {'points': array([[448.5, 290. ],
#          [453.5, 139.5]], dtype=float32)},
#  {'points': array([[453.5, 139.5],
#          [452. ,  98.5]], dtype=float32),
#   'elements': [{'points': array([[453., 122.],
#            [453., 105.]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[687., 325.],
#          [686., 504.]], dtype=float32),
#   'elements': [{'points': array([[687., 374.],
#            [687., 348.]], dtype=float32),
#     'type': 'door'},
#    {'points': array([[686.5, 496. ],
#            [686.5, 397. ]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[687., 325.],
#          [695., 509.]], dtype=float32)},
#  {'points': array([[686., 504.],
#          [542., 505.]], dtype=float32),
#   'elements': [{'points': array([[632. , 505.5],
#            [678. , 505.5]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[686., 504.],
#          [695., 509.]], dtype=float32)},
#  {'points': array([[542. , 505. ],
#          [504.5, 538. ]], dtype=float32),
#   'elements': [{'points': array([[514.1678 , 530.38257],
#            [528.5302 , 520.32886]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[504.5, 538. ],
#          [460. , 537.5]], dtype=float32),
#   'elements': [{'points': array([[464. , 538.5],
#            [501. , 538.5]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[460. , 537.5],
#          [419.5, 504. ]], dtype=float32),
#   'elements': [{'points': array([[428.5019, 513.5434],
#            [447.2038, 530.6868]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[419.5, 504. ],
#          [422. , 371.5]], dtype=float32)},
#  {'points': array([[419.5, 504. ],
#          [260. , 503. ]], dtype=float32),
#   'elements': [{'points': array([[288., 504.],
#            [387., 504.]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[422. , 371.5],
#          [448. , 369. ]], dtype=float32)},
#  {'points': array([[260., 503.],
#          [249., 508.]], dtype=float32)},
#  {'points': array([[337. ,  98. ],
#          [452. ,  98.5]], dtype=float32),
#   'elements': [{'points': array([[400.,  98.],
#            [444.,  98.]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[337.,  98.],
#          [171.,  99.]], dtype=float32),
#   'elements': [{'points': array([[216. ,  97.5],
#            [286. ,  97.5]], dtype=float32),
#     'type': 'window'}]},
#  {'points': array([[171. ,  99. ],
#          [ 49.5,  98.5]], dtype=float32),
#   'elements': [{'points': array([[ 57. ,  97.5],
#            [104. ,  97.5]], dtype=float32),
#     'type': 'window'}]})

# %%
walls = normalize_wall_points(walls, 5)
show_img(walls_closed, walls, element_lines)

# %%
from door_classification import crop_door

for wall in walls:
    if 'elements' in wall:
        for element in wall['elements']:
            if element['type'] != 'window':
                print('='*50)

                orig_img = original.copy()
                orig_img = cv2.circle(orig_img, np.intp(element['points'][0]), 4, (255, 0, 0,), 4)
                orig_img = cv2.circle(orig_img, np.intp(wall['points'][0]), 4, (0, 255, 0,), 4)
                plt.imshow(orig_img)
                plt.show()

                cropped_door = crop_door(element, wall, original)
                plt.imshow(cropped_door)
                plt.show()

                element['type'] = classify_door(element, wall, original)
                print(element['type'])
# Out:
# ==================================================
# single_dr
# ==================================================
# single_ur
# ==================================================
# single_dr
# ==================================================
# single_dl
# ==================================================
# single_ul
# ==================================================
# single_dl
# ==================================================
# single_dl
# ==================================================
# single_dr
# ==================================================
# single_ul
# ==================================================
# single_ul
# ==================================================
# single_ul
# ==================================================
# single_ul
# ==================================================
# single_ul
# ==================================================
# single_ur
# ==================================================
# single_dr

# %% [markdown]
# # Just call main

# %%
from recognition import *
import matplotlib.pyplot as plt

# %%
results = main()
results
# Out:
# 2022-04-27 15:46:51,603 INFO - Performing segmentation
# 2022-04-27 15:47:00,043 INFO - Simplifying contours
# 2022-04-27 15:47:00,177 INFO - Converting polygons to walls
# 2022-04-27 15:47:00,823 INFO - Calculating wall width
# 100%|██████████| 60/60 [00:00<00:00, 613800.59it/s]
# 2022-04-27 15:47:00,825 INFO - Identifying wall openings and associating them with their respective walls
# 100%|██████████| 60/60 [00:00<00:00, 807.74it/s]
# 2022-04-27 15:47:00,921 INFO - Classifying doors individually
# 100%|██████████| 60/60 [00:00<00:00, 181.58it/s]
# 2022-04-27 15:47:01,254 INFO - Retrieving icons
# 2022-04-27 15:47:01,256 INFO - Finished
# {'walls': [{'points': array([[171.5, 371.5],
#           [262. , 371.5]], dtype=float32),
#    'elements': [{'points': array([[197., 368.],
#             [224., 368.]], dtype=float32),
#      'type': 'single_dr'}]},
#   {'points': array([[171.5, 434. ],
#           [171.5, 371.5]], dtype=float32)},
#   {'points': array([[171.5, 371.5],
#           [171.5, 324. ]], dtype=float32),
#    'elements': [{'points': array([[170., 358.],
#             [170., 334.]], dtype=float32),
#      'type': 'single_ur'}]},
#   {'points': array([[262. , 434. ],
#           [262. , 371.5]], dtype=float32)},
#   {'points': array([[171.5, 434. ],
#           [262. , 434. ]], dtype=float32),
#    'elements': [{'points': array([[181. , 434.5],
#             [226. , 434.5]], dtype=float32),
#      'type': 'single_dr'}]},
#   {'points': array([[249., 509.],
#           [262., 434.]], dtype=float32),
#    'elements': [{'points': array([[258.5, 483. ],
#             [258.5, 454. ]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[262., 505.],
#           [262., 434.]], dtype=float32)},
#   {'points': array([[ 49.5, 434. ],
#           [171.5, 434. ]], dtype=float32),
#    'elements': [{'points': array([[ 57. , 434.5],
#             [102. , 434.5]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[ 49.5, 325.5],
#           [171.5, 324. ]], dtype=float32)},
#   {'points': array([[ 49.5, 434. ],
#           [ 49.5, 325.5]], dtype=float32),
#    'elements': [{'points': array([[ 47., 426.],
#             [ 47., 409.]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[ 49.5, 325.5],
#           [ 49.5, 255. ]], dtype=float32),
#    'elements': [{'points': array([[ 47.5, 310. ],
#             [ 47.5, 290. ]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[171.5, 324. ],
#           [171.5, 255. ]], dtype=float32),
#    'elements': [{'points': array([[169.89601, 281.0043 ],
#             [170.9792 , 307.00082]], dtype=float32),
#      'type': 'single_dl'}]},
#   {'points': array([[ 49.5, 255. ],
#           [171.5, 255. ]], dtype=float32)},
#   {'points': array([[ 49.5, 255. ],
#           [ 49.5,  99. ]], dtype=float32),
#    'elements': [{'points': array([[ 48., 226.],
#             [ 48., 207.]], dtype=float32),
#      'type': 'window'},
#     {'points': array([[ 48., 122.],
#             [ 48., 105.]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[171.5, 255. ],
#           [171.5, 212.5]], dtype=float32),
#    'elements': [{'points': array([[171., 246.],
#             [171., 221.]], dtype=float32),
#      'type': 'single_ul'}]},
#   {'points': array([[642. , 242.5],
#           [728. , 242.5]], dtype=float32)},
#   {'points': array([[631.5, 300. ],
#           [642. , 242.5]], dtype=float32)},
#   {'points': array([[642. , 242.5],
#           [642. , 220. ]], dtype=float32)},
#   {'points': array([[728. , 324. ],
#           [728. , 242.5]], dtype=float32),
#    'elements': [{'points': array([[726., 309.],
#             [726., 293.]], dtype=float32),
#      'type': 'single_dl'}]},
#   {'points': array([[728. , 242.5],
#           [728. , 220. ]], dtype=float32)},
#   {'points': array([[728., 324.],
#           [792., 324.]], dtype=float32),
#    'elements': [{'points': array([[740., 324.],
#             [754., 324.]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[687. , 325.5],
#           [728. , 324. ]], dtype=float32),
#    'elements': [{'points': array([[701. , 323.5],
#             [719. , 323.5]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[631.5, 300. ],
#           [645. , 324. ]], dtype=float32)},
#   {'points': array([[645. , 324. ],
#           [687. , 325.5]], dtype=float32)},
#   {'points': array([[614. , 293. ],
#           [631.5, 300. ]], dtype=float32)},
#   {'points': array([[728., 220.],
#           [792., 220.]], dtype=float32),
#    'elements': [{'points': array([[733., 219.],
#             [758., 219.]], dtype=float32),
#      'type': 'single_dl'}]},
#   {'points': array([[792., 324.],
#           [792., 220.]], dtype=float32)},
#   {'points': array([[792. , 220. ],
#           [792. , 139.5]], dtype=float32),
#    'elements': [{'points': array([[793.5, 202. ],
#             [793.5, 173. ]], dtype=float32),
#      'type': 'single_dr'}]},
#   {'points': array([[595., 220.],
#           [642., 220.]], dtype=float32),
#    'elements': [{'points': array([[612. , 219.5],
#             [633. , 219.5]], dtype=float32),
#      'type': 'single_ul'}]},
#   {'points': array([[595., 293.],
#           [595., 220.]], dtype=float32)},
#   {'points': array([[595. , 220. ],
#           [595. , 138.5]], dtype=float32),
#    'elements': [{'points': array([[594., 199.],
#             [594., 174.]], dtype=float32),
#      'type': 'single_ul'}]},
#   {'points': array([[574., 293.],
#           [595., 293.]], dtype=float32)},
#   {'points': array([[595., 293.],
#           [614., 293.]], dtype=float32)},
#   {'points': array([[262. , 212.5],
#           [337. , 212.5]], dtype=float32)},
#   {'points': array([[262. , 293. ],
#           [262. , 212.5]], dtype=float32)},
#   {'points': array([[171.5, 212.5],
#           [262. , 212.5]], dtype=float32),
#    'elements': [{'points': array([[201. , 212.5],
#             [226. , 212.5]], dtype=float32),
#      'type': 'single_ul'}]},
#   {'points': array([[337. , 293. ],
#           [337. , 212.5]], dtype=float32),
#    'elements': [{'points': array([[336.5, 260. ],
#             [336.5, 241. ]], dtype=float32),
#      'type': 'single_ul'}]},
#   {'points': array([[337. , 212.5],
#           [337. ,  99. ]], dtype=float32)},
#   {'points': array([[262., 293.],
#           [337., 293.]], dtype=float32)},
#   {'points': array([[337., 293.],
#           [452., 293.]], dtype=float32),
#    'elements': [{'points': array([[344., 290.],
#             [367., 290.]], dtype=float32),
#      'type': 'single_ul'}]},
#   {'points': array([[595. , 138.5],
#           [792. , 139.5]], dtype=float32),
#    'elements': [{'points': array([[674., 138.],
#             [714., 138.]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[792. , 139.5],
#           [805. , 138.5]], dtype=float32)},
#   {'points': array([[453.5, 139.5],
#           [595. , 138.5]], dtype=float32),
#    'elements': [{'points': array([[558., 138.],
#             [586., 138.]], dtype=float32),
#      'type': 'single_ur'},
#     {'points': array([[472. , 138.5],
#             [510. , 138.5]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[171.5, 212.5],
#           [171.5,  99. ]], dtype=float32)},
#   {'points': array([[452. , 293. ],
#           [453.5, 139.5]], dtype=float32)},
#   {'points': array([[452. ,  99. ],
#           [453.5, 139.5]], dtype=float32),
#    'elements': [{'points': array([[453., 122.],
#             [453., 105.]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[687. , 505. ],
#           [687. , 325.5]], dtype=float32),
#    'elements': [{'points': array([[687., 374.],
#             [687., 348.]], dtype=float32),
#      'type': 'single_dr'},
#     {'points': array([[686.5, 496. ],
#             [686.5, 397. ]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[687. , 325.5],
#           [695. , 509. ]], dtype=float32)},
#   {'points': array([[542., 505.],
#           [687., 505.]], dtype=float32),
#    'elements': [{'points': array([[632. , 505.5],
#             [678. , 505.5]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[687., 505.],
#           [695., 509.]], dtype=float32)},
#   {'points': array([[504.5, 538. ],
#           [542. , 505. ]], dtype=float32),
#    'elements': [{'points': array([[514.1678 , 530.38257],
#             [528.5302 , 520.32886]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[460. , 538. ],
#           [504.5, 538. ]], dtype=float32),
#    'elements': [{'points': array([[464. , 538.5],
#             [501. , 538.5]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[422., 505.],
#           [460., 538.]], dtype=float32),
#    'elements': [{'points': array([[428.5019, 513.5434],
#             [447.2038, 530.6868]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[422. , 505. ],
#           [422. , 371.5]], dtype=float32)},
#   {'points': array([[262., 505.],
#           [422., 505.]], dtype=float32),
#    'elements': [{'points': array([[288., 504.],
#             [387., 504.]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[422. , 371.5],
#           [452. , 371.5]], dtype=float32)},
#   {'points': array([[249., 509.],
#           [262., 505.]], dtype=float32)},
#   {'points': array([[337.,  99.],
#           [452.,  99.]], dtype=float32),
#    'elements': [{'points': array([[400.,  98.],
#             [444.,  98.]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[171.5,  99. ],
#           [337. ,  99. ]], dtype=float32),
#    'elements': [{'points': array([[216. ,  97.5],
#             [286. ,  97.5]], dtype=float32),
#      'type': 'window'}]},
#   {'points': array([[ 49.5,  99. ],
#           [171.5,  99. ]], dtype=float32),
#    'elements': [{'points': array([[ 57. ,  97.5],
#             [104. ,  97.5]], dtype=float32),
#      'type': 'window'}]}],
#  'icons': ({'points': array([[233., 371.],
#           [258., 371.],
#           [258., 429.],
#           [233., 429.]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[324., 285.],
#           [324., 273.],
#           [332., 273.],
#           [332., 285.]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[374., 264.],
#           [447., 264.],
#           [447., 287.],
#           [374., 287.]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[ 53.84368, 251.59718],
#           [ 54.26008, 228.69566],
#           [131.3255 , 230.09685],
#           [130.90912, 252.99837]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[774.7468 , 225.10045],
#           [784.57214, 223.79039],
#           [787.19226, 243.44106],
#           [777.36694, 244.75111]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[644., 239.],
#           [644., 217.],
#           [723., 217.],
#           [723., 239.]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[316., 217.],
#           [333., 217.],
#           [333., 231.],
#           [316., 231.]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[234., 216.],
#           [258., 216.],
#           [258., 291.],
#           [234., 291.]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[762.     , 163.00002],
#           [763.     , 162.00002],
#           [764.     , 163.00002],
#           [763.     , 164.00002]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[758.00006, 163.00005],
#           [759.00006, 162.00005],
#           [760.00006, 163.00005],
#           [759.00006, 164.00005]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[754.00006, 162.99998],
#           [755.50006, 161.49998],
#           [757.00006, 162.99998],
#           [755.50006, 164.49998]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[769.5001 , 162.49998],
#           [771.5001 , 160.49998],
#           [774.0001 , 162.99998],
#           [772.0001 , 164.99998]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[770., 160.],
#           [770., 158.],
#           [775., 158.],
#           [775., 160.]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[762.00006, 159.00005],
#           [763.00006, 158.00005],
#           [764.00006, 159.00005],
#           [763.00006, 160.00005]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[769.5001 , 152.50005],
#           [771.5001 , 150.50005],
#           [773.0001 , 152.00005],
#           [771.0001 , 154.00005]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[746., 151.],
#           [746., 151.],
#           [745., 151.],
#           [745., 151.]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[762., 147.],
#           [772., 147.],
#           [772., 152.],
#           [762., 152.]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[619., 146.],
#           [667., 146.],
#           [667., 168.],
#           [619., 168.]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[722., 145.],
#           [787., 145.],
#           [787., 167.],
#           [722., 167.]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[174., 104.],
#           [196., 104.],
#           [196., 209.],
#           [174., 209.]], dtype=float32),
#    'type': 'closet'},
#   {'points': array([[616., 261.],
#           [633., 261.],
#           [633., 287.],
#           [616., 287.]], dtype=float32),
#    'type': 'toilet'},
#   {'points': array([[ 95., 259.],
#           [111., 259.],
#           [111., 285.],
#           [ 95., 285.]], dtype=float32),
#    'type': 'toilet'},
#   {'points': array([[131., 259.],
#           [153., 259.],
#           [153., 275.],
#           [131., 275.]], dtype=float32),
#    'type': 'sink'},
#   {'points': array([[596., 229.],
#           [612., 229.],
#           [612., 247.],
#           [596., 247.]], dtype=float32),
#    'type': 'sink'},
#   {'points': array([[455., 216.],
#           [474., 216.],
#           [474., 245.],
#           [455., 245.]], dtype=float32),
#    'type': 'sink'})}

# %%
original = cv2.imread("original.png")
im = np.full(original.shape, 255).astype(np.uint8)

# %%
reconstr = im.copy()
for wall in results['walls']:
    s, e = wall['points']
    reconstr = cv2.line(reconstr, np.intp(s), np.intp(e), (0, 0, 0), 3)

    if 'elements'  in wall:
        for el in wall['elements']:
            s, e = el['points']
            if el['type'] == 'window':
                reconstr = cv2.line(reconstr, np.intp(s), np.intp(e), (147, 181, 198), 3)
            else:
                reconstr = cv2.line(reconstr, np.intp(s), np.intp(e), (94, 80, 63), 3)
                reconstr = cv2.putText(
                    reconstr, el['type'][-2:],
                    np.intp(s),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (230, 80, 63), 1, 2
                )

icons = ('closet', 'toilet', 'sink', 'bathtub')
colors = ((145, 91, 36), (133, 218, 255),  (58, 126, 156), (201, 30, 173))
for icon in results['icons']:
    # pts = np.intp(icon['points'])
    # print(pts, pts.shape, pts.reshape((-1, 1, 2)))
    reconstr = cv2.drawContours(reconstr, [np.intp(icon['points'])], 0, colors[icons.index(icon['type'])], 3)

plt.figure(figsize=(15, 15))
plt.imshow(original)

plt.figure(figsize=(15, 15))
plt.imshow(reconstr)
plt.show()

# %%
original = cv2.imread('original.png')
# rooms_pred, icons_pred = predict(original)

# Decorative elements
closets_pixels = as_image(icons_pred == 3)
toilets_pixels = as_image(icons_pred == 5)
sinks_pixels = as_image(icons_pred == 6)
bathtubs_pixels = as_image(icons_pred == 9)

plt.imshow(closets_pixels, cmap='gray')
